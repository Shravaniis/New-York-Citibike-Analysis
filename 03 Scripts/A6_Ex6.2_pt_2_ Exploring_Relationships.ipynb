# %% [markdown]
# # 6.2.2 Exploring relationships

# %% [markdown]
# ### This script contains the following:
#
# #### 1. Importing Visualization Libraries and Data
# #### 2. Data Cleaning
# #### 3. Exploring Relationships
#      Correlations
#      Scatterplots
#      Pair Plots

# %% [markdown]
# ### 1. Importing Visualization Libraries and Data

# %%
import pandas as pd 
from pandas import Grouper
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os
# %matplotlib inline
import re
import calendar

# %%
# Define path
path = r'C:\Users\shrav\_Data_Analysis_CF\Citi_bikes_project'

# %%
# Import data
citi = pd.read_csv(os.path.join(path, '02 Data','Prepared data', 'citi_3.csv'), index_col = False)

# %% [markdown]
# ### 2. Data Cleaning

# %%
citi.head()
# Out:
#    Unnamed: 0 day_of_week  start_hour  start_station_id  \
# 0           0         Mon          18               523
# 1           1         Thu          18               257
# 2           2         Wed          19               479
# 3           3         Sat          11               527
# 4           4         Fri          22               293
#
#         start_station_name  start_station_latitude  start_station_longitude  \
# 0          W 38 St & 8 Ave               40.754666               -73.991382
# 1  Lispenard St & Broadway               40.719392               -74.002472
# 2          9 Ave & W 45 St               40.760193               -73.991255
# 3          E 33 St & 1 Ave               40.743156               -73.974347
# 4    Lafayette St & E 8 St               40.730287               -73.990765
#
#    end_station_id     end_station_name  end_station_latitude  \
# 0             334      W 20 St & 7 Ave             40.742388
# 1             236  St Marks Pl & 2 Ave             40.728419
# 2             513     W 56 St & 10 Ave             40.768254
# 3             441      E 52 St & 2 Ave             40.756014
# 4             432    E 7 St & Avenue A             40.726218
#
#    end_station_longitude  trip_duration  subscriber  birth_year  gender  \
# 0             -73.997262            993  Subscriber      1968.0       2
# 1             -73.987140            581  Subscriber      1983.0       1
# 2             -73.988639            361  Subscriber      1989.0       1
# 3             -73.967416            561  Subscriber      1988.0       2
# 4             -73.983799            427  Subscriber      1986.0       2
#
#             ride_start             ride_end     Trip category
# 0  2013-09-09 18:18:55  2013-09-09 18:35:28     10-20 minutes
# 1  2013-09-12 18:38:53  2013-09-12 18:48:34  under 10 minutes
# 2  2013-09-18 19:44:04  2013-09-18 19:50:05  under 10 minutes
# 3  2013-09-28 11:54:37  2013-09-28 12:03:58  under 10 minutes
# 4  2013-09-27 22:01:01  2013-09-27 22:08:08  under 10 minutes

# %%
citi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42993 entries, 0 to 42992
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               42993 non-null  int64
#  1   day_of_week              42993 non-null  object
#  2   start_hour               42993 non-null  int64
#  3   start_station_id         42993 non-null  int64
#  4   start_station_name       42993 non-null  object
#  5   start_station_latitude   42993 non-null  float64
#  6   start_station_longitude  42993 non-null  float64
#  7   end_station_id           42993 non-null  int64
#  8   end_station_name         42993 non-null  object
#  9   end_station_latitude     42993 non-null  float64
#  10  end_station_longitude    42993 non-null  float64
#  11  trip_duration            42993 non-null  int64
#  12  subscriber               42993 non-null  object
#  13  birth_year               42993 non-null  float64
#  14  gender                   42993 non-null  int64
#  15  ride_start               42993 non-null  object
#  16  ride_end                 42993 non-null  object
#  17  Trip category            42993 non-null  object
# dtypes: float64(5), int64(6), object(7)
# memory usage: 5.9+ MB

# %%
# Define data types for specific columns
data_types = {
    'start_time': 'datetime64',
    'end_time': 'datetime64'
}

# %%
citi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42993 entries, 0 to 42992
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               42993 non-null  int64
#  1   day_of_week              42993 non-null  object
#  2   start_hour               42993 non-null  int64
#  3   start_station_id         42993 non-null  int64
#  4   start_station_name       42993 non-null  object
#  5   start_station_latitude   42993 non-null  float64
#  6   start_station_longitude  42993 non-null  float64
#  7   end_station_id           42993 non-null  int64
#  8   end_station_name         42993 non-null  object
#  9   end_station_latitude     42993 non-null  float64
#  10  end_station_longitude    42993 non-null  float64
#  11  trip_duration            42993 non-null  int64
#  12  subscriber               42993 non-null  object
#  13  birth_year               42993 non-null  float64
#  14  gender                   42993 non-null  int64
#  15  ride_start               42993 non-null  object
#  16  ride_end                 42993 non-null  object
#  17  Trip category            42993 non-null  object
# dtypes: float64(5), int64(6), object(7)
# memory usage: 5.9+ MB

# %%
#date time conversion
file_path = os.path.join(path, '02 Data','prepared data','citi_3.csv')

# %%
parse_dates = ['ride_start', 'ride_end']

# %%
citi = pd.read_csv(file_path, parse_dates=parse_dates)

# %%
citi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42993 entries, 0 to 42992
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               42993 non-null  int64
#  1   day_of_week              42993 non-null  object
#  2   start_hour               42993 non-null  int64
#  3   start_station_id         42993 non-null  int64
#  4   start_station_name       42993 non-null  object
#  5   start_station_latitude   42993 non-null  float64
#  6   start_station_longitude  42993 non-null  float64
#  7   end_station_id           42993 non-null  int64
#  8   end_station_name         42993 non-null  object
#  9   end_station_latitude     42993 non-null  float64
#  10  end_station_longitude    42993 non-null  float64
#  11  trip_duration            42993 non-null  int64
#  12  subscriber               42993 non-null  object
#  13  birth_year               42993 non-null  float64
#  14  gender                   42993 non-null  int64
#  15  ride_start               42993 non-null  datetime64[ns]
#  16  ride_end                 42993 non-null  datetime64[ns]
#  17  Trip category            42993 non-null  object
# dtypes: datetime64[ns](2), float64(5), int64(6), object(5)
# memory usage: 5.9+ MB

# %%
citi['ride_start_date'] = citi['ride_start'].dt.date
citi['ride_start_time'] = citi['ride_start'].dt.time

# %%
citi.head()
# Out:
#    Unnamed: 0 day_of_week  start_hour  start_station_id  \
# 0           0         Mon          18               523
# 1           1         Thu          18               257
# 2           2         Wed          19               479
# 3           3         Sat          11               527
# 4           4         Fri          22               293
#
#         start_station_name  start_station_latitude  start_station_longitude  \
# 0          W 38 St & 8 Ave               40.754666               -73.991382
# 1  Lispenard St & Broadway               40.719392               -74.002472
# 2          9 Ave & W 45 St               40.760193               -73.991255
# 3          E 33 St & 1 Ave               40.743156               -73.974347
# 4    Lafayette St & E 8 St               40.730287               -73.990765
#
#    end_station_id     end_station_name  end_station_latitude  \
# 0             334      W 20 St & 7 Ave             40.742388
# 1             236  St Marks Pl & 2 Ave             40.728419
# 2             513     W 56 St & 10 Ave             40.768254
# 3             441      E 52 St & 2 Ave             40.756014
# 4             432    E 7 St & Avenue A             40.726218
#
#    end_station_longitude  trip_duration  subscriber  birth_year  gender  \
# 0             -73.997262            993  Subscriber      1968.0       2
# 1             -73.987140            581  Subscriber      1983.0       1
# 2             -73.988639            361  Subscriber      1989.0       1
# 3             -73.967416            561  Subscriber      1988.0       2
# 4             -73.983799            427  Subscriber      1986.0       2
#
#            ride_start            ride_end     Trip category ride_start_date  \
# 0 2013-09-09 18:18:55 2013-09-09 18:35:28     10-20 minutes      2013-09-09
# 1 2013-09-12 18:38:53 2013-09-12 18:48:34  under 10 minutes      2013-09-12
# 2 2013-09-18 19:44:04 2013-09-18 19:50:05  under 10 minutes      2013-09-18
# 3 2013-09-28 11:54:37 2013-09-28 12:03:58  under 10 minutes      2013-09-28
# 4 2013-09-27 22:01:01 2013-09-27 22:08:08  under 10 minutes      2013-09-27
#
#   ride_start_time
# 0        18:18:55
# 1        18:38:53
# 2        19:44:04
# 3        11:54:37
# 4        22:01:01

# %%
#seeing how many rides are in an hour
citi['start_hour'].value_counts(dropna=False)
# Out:
# start_hour
# 17    4398
# 18    4280
# 8     3127
# 16    3046
# 19    2930
# 9     2598
# 15    2436
# 13    2408
# 14    2401
# 12    2353
# 7     1980
# 20    1932
# 11    1841
# 10    1827
# 21    1371
# 22    1159
# 6      889
# 23     803
# 0      420
# 1      266
# 5      195
# 2      162
# 3       96
# 4       75
# Name: count, dtype: int64

# %%
#wanting to see rides per day using group function
rides_per_day=citi.groupby(citi['ride_start'].dt.date).size()

# %%
rides_per_day
# Out:
# ride_start
# 2013-09-01     778
# 2013-09-02     743
# 2013-09-03    1397
# 2013-09-04    1543
# 2013-09-05    1435
# 2013-09-06    1522
# 2013-09-07    1205
# 2013-09-08    1206
# 2013-09-09    1487
# 2013-09-10    1646
# 2013-09-11    1587
# 2013-09-12    1401
# 2013-09-13    1701
# 2013-09-14    1203
# 2013-09-15    1239
# 2013-09-16    1344
# 2013-09-17    1658
# 2013-09-18    1681
# 2013-09-19    1634
# 2013-09-20    1777
# 2013-09-21    1228
# 2013-09-22    1121
# 2013-09-23    1557
# 2013-09-24    1728
# 2013-09-25    1679
# 2013-09-26    1742
# 2013-09-27    1594
# 2013-09-28    1329
# 2013-09-29    1162
# 2013-09-30    1666
# dtype: int64

# %%
# number of rides each day
citi['ride_start_date'].value_counts(dropna=False)
# Out:
# ride_start_date
# 2013-09-20    1777
# 2013-09-26    1742
# 2013-09-24    1728
# 2013-09-13    1701
# 2013-09-18    1681
# 2013-09-25    1679
# 2013-09-30    1666
# 2013-09-17    1658
# 2013-09-10    1646
# 2013-09-19    1634
# 2013-09-27    1594
# 2013-09-11    1587
# 2013-09-23    1557
# 2013-09-04    1543
# 2013-09-06    1522
# 2013-09-09    1487
# 2013-09-05    1435
# 2013-09-12    1401
# 2013-09-03    1397
# 2013-09-16    1344
# 2013-09-28    1329
# 2013-09-15    1239
# 2013-09-21    1228
# 2013-09-08    1206
# 2013-09-07    1205
# 2013-09-14    1203
# 2013-09-29    1162
# 2013-09-22    1121
# 2013-09-01     778
# 2013-09-02     743
# Name: count, dtype: int64

# %%
# avg hour rides occurs each day
citi.groupby('ride_start_date').agg({'start_hour':['mean']})
# Out:
#                 start_hour
#                       mean
# ride_start_date
# 2013-09-01       14.597686
# 2013-09-02       14.352624
# 2013-09-03       14.324982
# 2013-09-04       13.953986
# 2013-09-05       14.157491
# 2013-09-06       13.992773
# 2013-09-07       14.350207
# 2013-09-08       14.338308
# 2013-09-09       14.071957
# 2013-09-10       14.222357
# 2013-09-11       13.788280
# 2013-09-12       13.111349
# 2013-09-13       13.711346
# 2013-09-14       14.174564
# 2013-09-15       14.255851
# 2013-09-16       14.607143
# 2013-09-17       13.979493
# 2013-09-18       14.157644
# 2013-09-19       14.074663
# 2013-09-20       14.019696
# 2013-09-21       13.780945
# 2013-09-22       14.796610
# 2013-09-23       14.339114
# 2013-09-24       13.947917
# 2013-09-25       14.055390
# 2013-09-26       13.865672
# 2013-09-27       13.986826
# 2013-09-28       14.237773
# 2013-09-29       13.963855
# 2013-09-30       14.124250

# %%
#avg hour rides occur by day of week
citi.groupby('day_of_week').agg({'start_hour':['mean']})
# Out:
#             start_hour
#                   mean
# day_of_week
# Fri          13.925993
# Mon          14.282478
# Sat          14.136757
# Sun          14.370687
# Thu          13.817933
# Tue          14.108259
# Wed          13.992450

# %% [markdown]
# #### with this I was able to answer another question that the time of day does not signifigantly change the busy hours for citi bike

# %%
#saving DF to csv
citi.to_csv(os.path.join(path, '02 Data','prepared data', 'citi_3.csv'))

# %% [markdown]
# ### 3. Exploring relationships

# %%
citi.head()
# Out:
#    Unnamed: 0 day_of_week  start_hour  start_station_id  \
# 0           0         Mon          18               523
# 1           1         Thu          18               257
# 2           2         Wed          19               479
# 3           3         Sat          11               527
# 4           4         Fri          22               293
#
#         start_station_name  start_station_latitude  start_station_longitude  \
# 0          W 38 St & 8 Ave               40.754666               -73.991382
# 1  Lispenard St & Broadway               40.719392               -74.002472
# 2          9 Ave & W 45 St               40.760193               -73.991255
# 3          E 33 St & 1 Ave               40.743156               -73.974347
# 4    Lafayette St & E 8 St               40.730287               -73.990765
#
#    end_station_id     end_station_name  end_station_latitude  \
# 0             334      W 20 St & 7 Ave             40.742388
# 1             236  St Marks Pl & 2 Ave             40.728419
# 2             513     W 56 St & 10 Ave             40.768254
# 3             441      E 52 St & 2 Ave             40.756014
# 4             432    E 7 St & Avenue A             40.726218
#
#    end_station_longitude  trip_duration  subscriber  birth_year  gender  \
# 0             -73.997262            993  Subscriber      1968.0       2
# 1             -73.987140            581  Subscriber      1983.0       1
# 2             -73.988639            361  Subscriber      1989.0       1
# 3             -73.967416            561  Subscriber      1988.0       2
# 4             -73.983799            427  Subscriber      1986.0       2
#
#            ride_start            ride_end     Trip category ride_start_date  \
# 0 2013-09-09 18:18:55 2013-09-09 18:35:28     10-20 minutes      2013-09-09
# 1 2013-09-12 18:38:53 2013-09-12 18:48:34  under 10 minutes      2013-09-12
# 2 2013-09-18 19:44:04 2013-09-18 19:50:05  under 10 minutes      2013-09-18
# 3 2013-09-28 11:54:37 2013-09-28 12:03:58  under 10 minutes      2013-09-28
# 4 2013-09-27 22:01:01 2013-09-27 22:08:08  under 10 minutes      2013-09-27
#
#   ride_start_time
# 0        18:18:55
# 1        18:38:53
# 2        19:44:04
# 3        11:54:37
# 4        22:01:01

# %%
# make a subset 
sub=citi[['start_hour','start_station_latitude','start_station_longitude','end_station_latitude','end_station_longitude','trip_duration','birth_year',]]

# %%
# making a correlation heatmap using matplotlib with most practical variables
plt.matshow(sub.corr()),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x1aa35635fd0>, None)

# %%
# add labels and legend
f= plt.figure(figsize=(8,8))
# figure size
plt.matshow(sub.corr(), fignum=f.number)
# type of plot
plt.xticks(range(sub.shape[1]),sub.columns, fontsize=14, rotation=45)
#x axis labels
plt.yticks(range(sub.shape[1]),sub.columns, fontsize=14)
# y axis labels
cb=plt.colorbar()
# add a color legend
cb.ax.tick_params(labelsize=14)
# add a font size
plt.title('Correlation Matrix',fontsize=14)
# add title
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
#subplot in matplot lib
f,ax=plt.subplots(figsize=(10,10))
#create the correlationheat map in seaborn by applying a heatmap onto the correlation matrix
corr=sns.heatmap(sub.corr(), annot = True, ax=ax)

# %%
# smaller pair plot
sub_1=citi[['start_hour','trip_duration','birth_year']]

# %%
# create a pair plot of selected variables
g=sns.pairplot(sub_1)

# %%
# avg trip duration for start hour
citi.groupby('start_hour').agg({'trip_duration':['mean','min','max']})
# Out:
#            trip_duration
#                     mean min   max
# start_hour
# 0             748.716667  63  2697
# 1             702.657895  95  2697
# 2             659.561728  69  2403
# 3             687.020833  82  2697
# 4             667.106667  90  2697
# 5             605.348718  81  2697
# 6             648.613048  62  2697
# 7             727.038384  62  2697
# 8             756.595459  60  2697
# 9             728.346035  64  2697
# 10            745.684729  66  2697
# 11            760.065182  60  2697
# 12            732.083723  71  2697
# 13            748.196844  63  2697
# 14            788.499792  60  2697
# 15            784.350575  62  2697
# 16            809.883454  62  2697
# 17            822.308322  60  2697
# 18            826.911215  64  2697
# 19            782.310580  63  2697
# 20            776.412526  68  2697
# 21            771.610503  62  2697
# 22            742.789474  61  2697
# 23            730.199253  60  2697

# %%
#avg trip duration for day of week
citi.groupby('day_of_week').agg({'trip_duration':['mean','min','max']})
# Out:
#             trip_duration
#                      mean min   max
# day_of_week
# Fri            764.061723  60  2697
# Mon            761.585552  60  2697
# Sat            804.035045  60  2697
# Sun            814.107701  60  2697
# Thu            750.656632  62  2697
# Tue            749.886452  60  2697
# Wed            763.153621  60  2697

# %%
#avg min maxstart hour by day
citi.groupby('ride_start_date').agg({'start_hour':['mean','min','max']})
# Out:
#                 start_hour
#                       mean min max
# ride_start_date
# 2013-09-01       14.597686   0  23
# 2013-09-02       14.352624   0  23
# 2013-09-03       14.324982   0  23
# 2013-09-04       13.953986   0  23
# 2013-09-05       14.157491   0  23
# 2013-09-06       13.992773   0  23
# 2013-09-07       14.350207   0  23
# 2013-09-08       14.338308   0  23
# 2013-09-09       14.071957   0  23
# 2013-09-10       14.222357   0  23
# 2013-09-11       13.788280   0  23
# 2013-09-12       13.111349   0  23
# 2013-09-13       13.711346   0  23
# 2013-09-14       14.174564   0  23
# 2013-09-15       14.255851   0  23
# 2013-09-16       14.607143   0  23
# 2013-09-17       13.979493   0  23
# 2013-09-18       14.157644   0  23
# 2013-09-19       14.074663   0  23
# 2013-09-20       14.019696   0  23
# 2013-09-21       13.780945   0  23
# 2013-09-22       14.796610   0  23
# 2013-09-23       14.339114   0  23
# 2013-09-24       13.947917   0  23
# 2013-09-25       14.055390   0  23
# 2013-09-26       13.865672   0  23
# 2013-09-27       13.986826   0  23
# 2013-09-28       14.237773   0  23
# 2013-09-29       13.963855   0  23
# 2013-09-30       14.124250   0  23

# %%
# seeing if different stations vary based on day
citi.groupby('start_station_id').agg({'trip_duration':['mean','min','max']})
# Out:
#                  trip_duration
#                           mean  min   max
# start_station_id
# 72                  942.550633   64  2697
# 79                  941.786885  156  2697
# 82                  745.220339   68  2109
# 83                  897.402778  142  2613
# 116                 643.992565   87  2697
# ...                        ...  ...   ...
# 2017                950.944444   98  2697
# 2021                662.913333   92  2697
# 2022               1012.041667  215  2596
# 2023                895.945946  171  2674
# 3002                893.024631   68  2697
#
# [330 rows x 3 columns]

# %%
# saving data
citi.to_csv(os.path.join(path, '02 Data','prepared data', 'citi_4.csv'))

# %%
citi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42993 entries, 0 to 42992
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               42993 non-null  int64
#  1   day_of_week              42993 non-null  object
#  2   start_hour               42993 non-null  int64
#  3   start_station_id         42993 non-null  int64
#  4   start_station_name       42993 non-null  object
#  5   start_station_latitude   42993 non-null  float64
#  6   start_station_longitude  42993 non-null  float64
#  7   end_station_id           42993 non-null  int64
#  8   end_station_name         42993 non-null  object
#  9   end_station_latitude     42993 non-null  float64
#  10  end_station_longitude    42993 non-null  float64
#  11  trip_duration            42993 non-null  int64
#  12  subscriber               42993 non-null  object
#  13  birth_year               42993 non-null  float64
#  14  gender                   42993 non-null  int64
#  15  ride_start               42993 non-null  datetime64[ns]
#  16  ride_end                 42993 non-null  datetime64[ns]
#  17  Trip category            42993 non-null  object
#  18  ride_start_date          42993 non-null  object
#  19  ride_start_time          42993 non-null  object
# dtypes: datetime64[ns](2), float64(5), int64(6), object(7)
# memory usage: 6.6+ MB

# %%
# create categorical plotin seaborn using trip category
sns.set(style="ticks")
g=sns.catplot(x="start_hour", y= "trip_duration", hue="Trip category", data=citi)

# %%
#saving CSV
#13 saving and exporting DF
citi.to_csv(os.path.join(path, '02 Data','prepared data', 'citi_4.csv'))
